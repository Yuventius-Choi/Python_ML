# %% [markdown]
# # Scikit-Learn 소개와 특징
#
# Scikit-Learn은 파이썬 ML 라이브러리 중 가장 많이 사용되는 라이브러리입니다.<br>
# 최근에는 DeepLearning이 강세여서 관심이 줄어들고는 있지만 데이터 분석에서는 여전히 강세입니다.
#
# Anaconda나 Colab 환경이라면 기본적으로 깔려있는 라이브러리라서 설치할 필요가 없지만,<br>
# 다른 환경이라면 설치가 필요합니다.

# %%
# !pip install scikit-learn

# %%
# 버전 확인
import sklearn

print(sklearn.__version__)
# Out:
# 1.3.2
